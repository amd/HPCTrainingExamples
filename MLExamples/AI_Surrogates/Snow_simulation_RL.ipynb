# %%
# Copyright (c) 2025 Advanced Micro Devices, Inc. All rights reserved This software is distributed under the MIT License, Contact: Alessandro Fanfarillo

# %%
import gym
from gym import spaces
import numpy as np

class DynamicSnowDensityEnv(gym.Env):
    def __init__(self):
        super(DynamicSnowDensityEnv, self).__init__()
        
        # Action space: Adjust alpha_T, alpha_u, and alpha_h (scaling factors)
        self.action_space = spaces.Box(low=np.array([0, 0, 0]), high=np.array([5, 20, 5]), dtype=np.float32)
        
        # Observation space: Temperature, Wind Speed, Humidity
        self.observation_space = spaces.Box(low=np.array([-40, 0, 0]), high=np.array([0, 20, 100]), dtype=np.float32)
        
        # Initialize environment variables (temperature, wind speed, and humidity)
        self.state = np.array([0, 5, 80])  # Initial temperature, wind speed, and humidity
        self.rho_min = 100  # Minimum snow density (kg/m³)
        self.T_ref = 0  # Reference temperature
    
    def reset(self):
        """
        Resets the environment to a random initial state (random weather conditions).
        """
        self.state = np.array([np.random.uniform(-20, 0),  # Random temperature
                               np.random.uniform(0, 20),   # Random wind speed
                               np.random.uniform(0, 100)]) # Random humidity
        return self.state

    def step(self, action):
        """
        Takes an action (adjusts alpha_T, alpha_u, alpha_h) and returns the next state, reward, and done flag.
        """
        # Unpack action into the scaling factors
        alpha_T, alpha_u, alpha_h = action
        
        # Unpack the current state (environmental variables)
        T, u, h = self.state
        
        # Predicted snow density based on the chosen parameters
        predicted_density = self.rho_min + alpha_T * (self.T_ref - T) + alpha_u * u + alpha_h * h
        
        # Simulated observed snow density (real-world value) based on a true model
        real_density = self.get_real_snow_density(T, u, h)
        
        # Reward is the negative absolute error (agent tries to minimize this)
        reward = -abs(predicted_density - real_density)
        
        # Change the weather conditions dynamically for the next step
        self.state = np.array([np.random.uniform(-20, 0),  # New temperature
                               np.random.uniform(0, 20),   # New wind speed
                               np.random.uniform(0, 100)]) # New humidity
        
        done = False  # Environment doesn't end (continuous)
        return self.state, reward, done, {}
    
    def get_real_snow_density(self, T, u, h):
        """
        Simulate the 'true' snow density based on real-world data or a known relationship.
        You can replace this with a real-world dataset or a more sophisticated model.
        """
        # Example fixed parameters for the true model
        alpha_T_true = 1.5
        alpha_u_true = 10
        alpha_h_true = 0.5
        
        # True snow density based on environmental conditions
        true_density = self.rho_min + alpha_T_true * (self.T_ref - T) + alpha_u_true * u + alpha_h_true * h
        
        # Clip the density to physical limits (100 to 600 kg/m³)
        return np.clip(true_density, 100, 600)

# %%
from stable_baselines3 import PPO

# Create the dynamic snow density environment
env = DynamicSnowDensityEnv()

# Create the PPO model
model = PPO("MlpPolicy", env, gamma=0, verbose=1)

# Train the model
model.learn(total_timesteps=300000)

# Save the trained model
model.save("dynamic_snow_density_model")
# Out:
# /home/alex/virtualenv/rl_ai/lib/python3.10/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# /home/alex/virtualenv/rl_ai/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /home/alex/virtualenv/rl_ai/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# -----------------------------
# | time/              |      |
# |    fps             | 1636 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1216        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.039030924 |
# |    clip_fraction        | 0.342       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.3        |
# |    explained_variance   | 0.00196     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.19e+03    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0552     |
# |    std                  | 1.02        |
# |    value_loss           | 1.54e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1152        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.058590956 |
# |    clip_fraction        | 0.455       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.36       |
# |    explained_variance   | 0.000837    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.35e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0713     |
# |    std                  | 1.04        |
# |    value_loss           | 1.2e+04     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1117       |
# |    iterations           | 4          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.06379304 |
# |    clip_fraction        | 0.428      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.36      |
# |    explained_variance   | 0.000298   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.17e+03   |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0743    |
# |    std                  | 1.03       |
# |    value_loss           | 9.48e+03   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1097        |
# |    iterations           | 5           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.059966348 |
# |    clip_fraction        | 0.466       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | 8.42e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.54e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0782     |
# |    std                  | 1.02        |
# |    value_loss           | 6.41e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1084        |
# |    iterations           | 6           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.054044586 |
# |    clip_fraction        | 0.41        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | 0.000114    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.64e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0716     |
# |    std                  | 0.998       |
# |    value_loss           | 4.29e+03    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1074       |
# |    iterations           | 7          |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.06259734 |
# |    clip_fraction        | 0.378      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.17      |
# |    explained_variance   | 7.87e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.01e+03   |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0694    |
# |    std                  | 0.967      |
# |    value_loss           | 3.33e+03   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1067        |
# |    iterations           | 8           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.042928282 |
# |    clip_fraction        | 0.346       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.08       |
# |    explained_variance   | 0.00805     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3e+03     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0562     |
# |    std                  | 0.953       |
# |    value_loss           | 2.23e+03    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1055       |
# |    iterations           | 9          |
# |    time_elapsed         | 17         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.02970794 |
# |    clip_fraction        | 0.282      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.01      |
# |    explained_variance   | 0.102      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 974        |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0557    |
# |    std                  | 0.942      |
# |    value_loss           | 1.96e+03   |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1046      |
# |    iterations           | 10        |
# |    time_elapsed         | 19        |
# |    total_timesteps      | 20480     |
# | train/                  |           |
# |    approx_kl            | 0.0263073 |
# |    clip_fraction        | 0.236     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.96     |
# |    explained_variance   | 0.16      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 726       |
# |    n_updates            | 90        |
# |    policy_gradient_loss | -0.0471   |
# |    std                  | 0.935     |
# |    value_loss           | 1.54e+03  |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1038        |
# |    iterations           | 11          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.022097278 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.91       |
# |    explained_variance   | 0.199       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 566         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.048      |
# |    std                  | 0.929       |
# |    value_loss           | 1.33e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1032        |
# |    iterations           | 12          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.021886963 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.85       |
# |    explained_variance   | 0.305       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 513         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.041      |
# |    std                  | 0.915       |
# |    value_loss           | 1.08e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1027        |
# |    iterations           | 13          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.021641467 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.78       |
# |    explained_variance   | 0.318       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 341         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0412     |
# |    std                  | 0.9         |
# |    value_loss           | 957         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1023        |
# |    iterations           | 14          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.031194422 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.69       |
# |    explained_variance   | 0.376       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 369         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.042      |
# |    std                  | 0.876       |
# |    value_loss           | 829         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1023        |
# |    iterations           | 15          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.026106868 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.58       |
# |    explained_variance   | 0.401       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 352         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0512     |
# |    std                  | 0.856       |
# |    value_loss           | 687         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1023        |
# |    iterations           | 16          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.033487976 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.48       |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 437         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0425     |
# |    std                  | 0.834       |
# |    value_loss           | 581         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1023        |
# |    iterations           | 17          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.036267675 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.36       |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 140         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0428     |
# |    std                  | 0.807       |
# |    value_loss           | 462         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1020        |
# |    iterations           | 18          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.047520977 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.22       |
# |    explained_variance   | 0.475       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 140         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0506     |
# |    std                  | 0.778       |
# |    value_loss           | 336         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1020       |
# |    iterations           | 19         |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.04668885 |
# |    clip_fraction        | 0.269      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.05      |
# |    explained_variance   | 0.434      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 170        |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.049     |
# |    std                  | 0.742      |
# |    value_loss           | 293        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1021       |
# |    iterations           | 20         |
# |    time_elapsed         | 40         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.04538566 |
# |    clip_fraction        | 0.297      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.9       |
# |    explained_variance   | 0.437      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 99.5       |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0512    |
# |    std                  | 0.716      |
# |    value_loss           | 221        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1018        |
# |    iterations           | 21          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.046654075 |
# |    clip_fraction        | 0.333       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.73       |
# |    explained_variance   | 0.446       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 84.2        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0541     |
# |    std                  | 0.681       |
# |    value_loss           | 201         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1016        |
# |    iterations           | 22          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.034440793 |
# |    clip_fraction        | 0.309       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.55       |
# |    explained_variance   | 0.409       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 75.3        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0419     |
# |    std                  | 0.647       |
# |    value_loss           | 163         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1016        |
# |    iterations           | 23          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.037940226 |
# |    clip_fraction        | 0.309       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.37       |
# |    explained_variance   | 0.376       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 75.3        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0464     |
# |    std                  | 0.61        |
# |    value_loss           | 128         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1014        |
# |    iterations           | 24          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.046011597 |
# |    clip_fraction        | 0.34        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | 0.416       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42          |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0466     |
# |    std                  | 0.575       |
# |    value_loss           | 111         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1013        |
# |    iterations           | 25          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.056338537 |
# |    clip_fraction        | 0.336       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.98       |
# |    explained_variance   | 0.353       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.8        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0362     |
# |    std                  | 0.547       |
# |    value_loss           | 91.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1011        |
# |    iterations           | 26          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.045159765 |
# |    clip_fraction        | 0.428       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0.346       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.4        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0243     |
# |    std                  | 0.512       |
# |    value_loss           | 79.2        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1012       |
# |    iterations           | 27         |
# |    time_elapsed         | 54         |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.04324028 |
# |    clip_fraction        | 0.406      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.57      |
# |    explained_variance   | 0.259      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 54.3       |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0167    |
# |    std                  | 0.481      |
# |    value_loss           | 68.2       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1010        |
# |    iterations           | 28          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.044612646 |
# |    clip_fraction        | 0.389       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.325       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.1        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0352     |
# |    std                  | 0.451       |
# |    value_loss           | 64.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1010        |
# |    iterations           | 29          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.055373296 |
# |    clip_fraction        | 0.433       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.246       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.5        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00182    |
# |    std                  | 0.423       |
# |    value_loss           | 51          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1009        |
# |    iterations           | 30          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.055508107 |
# |    clip_fraction        | 0.426       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.94       |
# |    explained_variance   | 0.224       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.4        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0165     |
# |    std                  | 0.398       |
# |    value_loss           | 44          |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1008       |
# |    iterations           | 31         |
# |    time_elapsed         | 62         |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.04569544 |
# |    clip_fraction        | 0.469      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.757     |
# |    explained_variance   | 0.224      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 17.3       |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0183    |
# |    std                  | 0.376      |
# |    value_loss           | 41         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1008        |
# |    iterations           | 32          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.061880495 |
# |    clip_fraction        | 0.464       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.575      |
# |    explained_variance   | 0.169       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.2        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0203     |
# |    std                  | 0.356       |
# |    value_loss           | 33.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1009        |
# |    iterations           | 33          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.041497406 |
# |    clip_fraction        | 0.387       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.368      |
# |    explained_variance   | 0.183       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.62        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.024      |
# |    std                  | 0.333       |
# |    value_loss           | 28.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1008        |
# |    iterations           | 34          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.056016967 |
# |    clip_fraction        | 0.467       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.156      |
# |    explained_variance   | 0.118       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.2        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.0054      |
# |    std                  | 0.312       |
# |    value_loss           | 25.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1008        |
# |    iterations           | 35          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.061729427 |
# |    clip_fraction        | 0.453       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0533      |
# |    explained_variance   | 0.137       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.1        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0131     |
# |    std                  | 0.293       |
# |    value_loss           | 21.8        |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1009      |
# |    iterations           | 36        |
# |    time_elapsed         | 73        |
# |    total_timesteps      | 73728     |
# | train/                  |           |
# |    approx_kl            | 0.0531265 |
# |    clip_fraction        | 0.457     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.259     |
# |    explained_variance   | 0.131     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 10.8      |
# |    n_updates            | 350       |
# |    policy_gradient_loss | -0.00936  |
# |    std                  | 0.275     |
# |    value_loss           | 19.9      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1009       |
# |    iterations           | 37         |
# |    time_elapsed         | 75         |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.11763168 |
# |    clip_fraction        | 0.496      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.455      |
# |    explained_variance   | 0.13       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 10.7       |
# |    n_updates            | 360        |
# |    policy_gradient_loss | 0.0157     |
# |    std                  | 0.258      |
# |    value_loss           | 15.9       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1008       |
# |    iterations           | 38         |
# |    time_elapsed         | 77         |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.11074558 |
# |    clip_fraction        | 0.53       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.636      |
# |    explained_variance   | 0.0805     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.67       |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0136    |
# |    std                  | 0.246      |
# |    value_loss           | 14.9       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1009       |
# |    iterations           | 39         |
# |    time_elapsed         | 79         |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.06206958 |
# |    clip_fraction        | 0.442      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.824      |
# |    explained_variance   | 0.0969     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.68       |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.00798   |
# |    std                  | 0.231      |
# |    value_loss           | 12.9       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1008       |
# |    iterations           | 40         |
# |    time_elapsed         | 81         |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.10245582 |
# |    clip_fraction        | 0.531      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.02       |
# |    explained_variance   | 0.122      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.75       |
# |    n_updates            | 390        |
# |    policy_gradient_loss | 0.00852    |
# |    std                  | 0.216      |
# |    value_loss           | 10.3       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1007       |
# |    iterations           | 41         |
# |    time_elapsed         | 83         |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.07602446 |
# |    clip_fraction        | 0.492      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.21       |
# |    explained_variance   | 0.121      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.06       |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0193    |
# |    std                  | 0.205      |
# |    value_loss           | 10.7       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1008       |
# |    iterations           | 42         |
# |    time_elapsed         | 85         |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.11253911 |
# |    clip_fraction        | 0.49       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.38       |
# |    explained_variance   | 0.127      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.24       |
# |    n_updates            | 410        |
# |    policy_gradient_loss | 0.01       |
# |    std                  | 0.192      |
# |    value_loss           | 9.19       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1008       |
# |    iterations           | 43         |
# |    time_elapsed         | 87         |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.14269331 |
# |    clip_fraction        | 0.536      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.57       |
# |    explained_variance   | 0.121      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.14       |
# |    n_updates            | 420        |
# |    policy_gradient_loss | 0.0366     |
# |    std                  | 0.182      |
# |    value_loss           | 7.87       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1008       |
# |    iterations           | 44         |
# |    time_elapsed         | 89         |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.09434854 |
# |    clip_fraction        | 0.574      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.73       |
# |    explained_variance   | 0.137      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.18       |
# |    n_updates            | 430        |
# |    policy_gradient_loss | 0.00013    |
# |    std                  | 0.174      |
# |    value_loss           | 7.23       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1008       |
# |    iterations           | 45         |
# |    time_elapsed         | 91         |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.09571797 |
# |    clip_fraction        | 0.526      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.89       |
# |    explained_variance   | 0.0896     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.37       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | 0.0222     |
# |    std                  | 0.164      |
# |    value_loss           | 6.37       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1008       |
# |    iterations           | 46         |
# |    time_elapsed         | 93         |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.14252575 |
# |    clip_fraction        | 0.551      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.07       |
# |    explained_variance   | 0.139      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.55       |
# |    n_updates            | 450        |
# |    policy_gradient_loss | 0.0369     |
# |    std                  | 0.155      |
# |    value_loss           | 5.3        |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1007      |
# |    iterations           | 47        |
# |    time_elapsed         | 95        |
# |    total_timesteps      | 96256     |
# | train/                  |           |
# |    approx_kl            | 0.1711771 |
# |    clip_fraction        | 0.582     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 2.24      |
# |    explained_variance   | 0.119     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.66      |
# |    n_updates            | 460       |
# |    policy_gradient_loss | 0.0569    |
# |    std                  | 0.147     |
# |    value_loss           | 5.07      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1006       |
# |    iterations           | 48         |
# |    time_elapsed         | 97         |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.15544862 |
# |    clip_fraction        | 0.607      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.41       |
# |    explained_variance   | 0.0958     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.28       |
# |    n_updates            | 470        |
# |    policy_gradient_loss | 0.0833     |
# |    std                  | 0.139      |
# |    value_loss           | 4.56       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1007       |
# |    iterations           | 49         |
# |    time_elapsed         | 99         |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.10360269 |
# |    clip_fraction        | 0.565      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.57       |
# |    explained_variance   | 0.123      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.01       |
# |    n_updates            | 480        |
# |    policy_gradient_loss | 0.0552     |
# |    std                  | 0.132      |
# |    value_loss           | 4.23       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1007       |
# |    iterations           | 50         |
# |    time_elapsed         | 101        |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.13638327 |
# |    clip_fraction        | 0.624      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.71       |
# |    explained_variance   | 0.104      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.33       |
# |    n_updates            | 490        |
# |    policy_gradient_loss | 0.0779     |
# |    std                  | 0.127      |
# |    value_loss           | 3.46       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1007      |
# |    iterations           | 51        |
# |    time_elapsed         | 103       |
# |    total_timesteps      | 104448    |
# | train/                  |           |
# |    approx_kl            | 0.3699758 |
# |    clip_fraction        | 0.624     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 2.85      |
# |    explained_variance   | 0.122     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.55      |
# |    n_updates            | 500       |
# |    policy_gradient_loss | 0.0718    |
# |    std                  | 0.122     |
# |    value_loss           | 3.32      |
# ---------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 1006     |
# |    iterations           | 52       |
# |    time_elapsed         | 105      |
# |    total_timesteps      | 106496   |
# | train/                  |          |
# |    approx_kl            | 5.295475 |
# |    clip_fraction        | 0.696    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 2.98     |
# |    explained_variance   | 0.108    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 2.78     |
# |    n_updates            | 510      |
# |    policy_gradient_loss | 0.112    |
# |    std                  | 0.117    |
# |    value_loss           | 3.15     |
# --------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1006      |
# |    iterations           | 53        |
# |    time_elapsed         | 107       |
# |    total_timesteps      | 108544    |
# | train/                  |           |
# |    approx_kl            | 1.9602909 |
# |    clip_fraction        | 0.604     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 3.07      |
# |    explained_variance   | 0.00113   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.29      |
# |    n_updates            | 520       |
# |    policy_gradient_loss | -0.0344   |
# |    std                  | 0.113     |
# |    value_loss           | 7.16      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1005      |
# |    iterations           | 54        |
# |    time_elapsed         | 110       |
# |    total_timesteps      | 110592    |
# | train/                  |           |
# |    approx_kl            | 25.183395 |
# |    clip_fraction        | 0.74      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 3.16      |
# |    explained_variance   | -2.3      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.58      |
# |    n_updates            | 530       |
# |    policy_gradient_loss | 0.0789    |
# |    std                  | 0.111     |
# |    value_loss           | 3.11      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1004      |
# |    iterations           | 55        |
# |    time_elapsed         | 112       |
# |    total_timesteps      | 112640    |
# | train/                  |           |
# |    approx_kl            | 3.2416685 |
# |    clip_fraction        | 0.729     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 3.19      |
# |    explained_variance   | -0.0738   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.05      |
# |    n_updates            | 540       |
# |    policy_gradient_loss | 0.0333    |
# |    std                  | 0.109     |
# |    value_loss           | 12.8      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1003       |
# |    iterations           | 56         |
# |    time_elapsed         | 114        |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# |    approx_kl            | 10.3222275 |
# |    clip_fraction        | 0.798      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 3.23       |
# |    explained_variance   | -1.6       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.19       |
# |    n_updates            | 550        |
# |    policy_gradient_loss | 0.0448     |
# |    std                  | 0.107      |
# |    value_loss           | 4.26       |
# ----------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 1004     |
# |    iterations           | 57       |
# |    time_elapsed         | 116      |
# |    total_timesteps      | 116736   |
# | train/                  |          |
# |    approx_kl            | 3.860036 |
# |    clip_fraction        | 0.775    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 3.3      |
# |    explained_variance   | 0.204    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 1.42     |
# |    n_updates            | 560      |
# |    policy_gradient_loss | 0.131    |
# |    std                  | 0.105    |
# |    value_loss           | 3.2      |
# --------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1004      |
# |    iterations           | 58        |
# |    time_elapsed         | 118       |
# |    total_timesteps      | 118784    |
# | train/                  |           |
# |    approx_kl            | 0.8335825 |
# |    clip_fraction        | 0.745     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 3.4       |
# |    explained_variance   | 0.0447    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.31      |
# |    n_updates            | 570       |
# |    policy_gradient_loss | 0.0552    |
# |    std                  | 0.101     |
# |    value_loss           | 3.27      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1004       |
# |    iterations           | 59         |
# |    time_elapsed         | 120        |
# |    total_timesteps      | 120832     |
# | train/                  |            |
# |    approx_kl            | 0.39066124 |
# |    clip_fraction        | 0.687      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 3.52       |
# |    explained_variance   | 0.00367    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.49       |
# |    n_updates            | 580        |
# |    policy_gradient_loss | 0.13       |
# |    std                  | 0.0964     |
# |    value_loss           | 2.6        |
# ----------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 1004     |
# |    iterations           | 60       |
# |    time_elapsed         | 122      |
# |    total_timesteps      | 122880   |
# | train/                  |          |
# |    approx_kl            | 83.50752 |
# |    clip_fraction        | 0.963    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 3.59     |
# |    explained_variance   | 0.126    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 1.14     |
# |    n_updates            | 590      |
# |    policy_gradient_loss | 3.49     |
# |    std                  | 0.0954   |
# |    value_loss           | 2.08     |
# --------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 1003     |
# |    iterations           | 61       |
# |    time_elapsed         | 124      |
# |    total_timesteps      | 124928   |
# | train/                  |          |
# |    approx_kl            | 4.990897 |
# ...
# |    n_updates            | 1250      |
# |    policy_gradient_loss | 0.0299    |
# |    std                  | 0.0635    |
# |    value_loss           | 4.38      |
# ---------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 987      |
# |    iterations           | 127      |
# |    time_elapsed         | 263      |
# |    total_timesteps      | 260096   |
# | train/                  |          |
# |    approx_kl            | 4.413369 |
# |    clip_fraction        | 0.742    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 4.64     |
# |    explained_variance   | 0.55     |
# |    learning_rate        | 0.0003   |
# |    loss                 | 1.85     |
# |    n_updates            | 1260     |
# |    policy_gradient_loss | -0.0122  |
# |    std                  | 0.0625   |
# |    value_loss           | 4.24     |
# --------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 987       |
# |    iterations           | 128       |
# |    time_elapsed         | 265       |
# |    total_timesteps      | 262144    |
# | train/                  |           |
# |    approx_kl            | 13.027283 |
# |    clip_fraction        | 0.88      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 4.68      |
# |    explained_variance   | 0.483     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.17      |
# |    n_updates            | 1270      |
# |    policy_gradient_loss | -0.00346  |
# |    std                  | 0.0616    |
# |    value_loss           | 2.78      |
# ---------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 987      |
# |    iterations           | 129      |
# |    time_elapsed         | 267      |
# |    total_timesteps      | 264192   |
# | train/                  |          |
# |    approx_kl            | 5.548855 |
# |    clip_fraction        | 0.851    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 4.7      |
# |    explained_variance   | 0.795    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.972    |
# |    n_updates            | 1280     |
# |    policy_gradient_loss | 0.047    |
# |    std                  | 0.0618   |
# |    value_loss           | 2.58     |
# --------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 986      |
# |    iterations           | 130      |
# |    time_elapsed         | 269      |
# |    total_timesteps      | 266240   |
# | train/                  |          |
# |    approx_kl            | 24.7917  |
# |    clip_fraction        | 0.824    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 4.72     |
# |    explained_variance   | 0.786    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.621    |
# |    n_updates            | 1290     |
# |    policy_gradient_loss | 0.0122   |
# |    std                  | 0.0613   |
# |    value_loss           | 2.26     |
# --------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 986       |
# |    iterations           | 131       |
# |    time_elapsed         | 271       |
# |    total_timesteps      | 268288    |
# | train/                  |           |
# |    approx_kl            | 3.6041603 |
# |    clip_fraction        | 0.789     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 4.77      |
# |    explained_variance   | 0.84      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.892     |
# |    n_updates            | 1300      |
# |    policy_gradient_loss | 0.0413    |
# |    std                  | 0.0606    |
# |    value_loss           | 2.18      |
# ---------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 986      |
# |    iterations           | 132      |
# |    time_elapsed         | 273      |
# |    total_timesteps      | 270336   |
# | train/                  |          |
# |    approx_kl            | 30.37774 |
# |    clip_fraction        | 0.902    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 4.79     |
# |    explained_variance   | 0.597    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.743    |
# |    n_updates            | 1310     |
# |    policy_gradient_loss | 0.175    |
# |    std                  | 0.0605   |
# |    value_loss           | 1.92     |
# --------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 986       |
# |    iterations           | 133       |
# |    time_elapsed         | 276       |
# |    total_timesteps      | 272384    |
# | train/                  |           |
# |    approx_kl            | 3.0404823 |
# |    clip_fraction        | 0.774     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 4.8       |
# |    explained_variance   | -0.048    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.16      |
# |    n_updates            | 1320      |
# |    policy_gradient_loss | 0.0139    |
# |    std                  | 0.0598    |
# |    value_loss           | 4.13      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 986       |
# |    iterations           | 134       |
# |    time_elapsed         | 278       |
# |    total_timesteps      | 274432    |
# | train/                  |           |
# |    approx_kl            | 151.70093 |
# |    clip_fraction        | 0.949     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 4.82      |
# |    explained_variance   | -0.645    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.1       |
# |    n_updates            | 1330      |
# |    policy_gradient_loss | 0.268     |
# |    std                  | 0.0597    |
# |    value_loss           | 2.27      |
# ---------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 986      |
# |    iterations           | 135      |
# |    time_elapsed         | 280      |
# |    total_timesteps      | 276480   |
# | train/                  |          |
# |    approx_kl            | 8.167033 |
# |    clip_fraction        | 0.775    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 4.8      |
# |    explained_variance   | 0.015    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 1.78     |
# |    n_updates            | 1340     |
# |    policy_gradient_loss | 0.114    |
# |    std                  | 0.0601   |
# |    value_loss           | 26.7     |
# --------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 986      |
# |    iterations           | 136      |
# |    time_elapsed         | 282      |
# |    total_timesteps      | 278528   |
# | train/                  |          |
# |    approx_kl            | 5.706379 |
# |    clip_fraction        | 0.846    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 4.78     |
# |    explained_variance   | 0.421    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 1.46     |
# |    n_updates            | 1350     |
# |    policy_gradient_loss | -0.00389 |
# |    std                  | 0.0595   |
# |    value_loss           | 3.81     |
# --------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 986      |
# |    iterations           | 137      |
# |    time_elapsed         | 284      |
# |    total_timesteps      | 280576   |
# | train/                  |          |
# |    approx_kl            | 4.556738 |
# |    clip_fraction        | 0.858    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 4.81     |
# |    explained_variance   | 0.716    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 1.45     |
# |    n_updates            | 1360     |
# |    policy_gradient_loss | -0.00474 |
# |    std                  | 0.0588   |
# |    value_loss           | 3.61     |
# --------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 986       |
# |    iterations           | 138       |
# |    time_elapsed         | 286       |
# |    total_timesteps      | 282624    |
# | train/                  |           |
# |    approx_kl            | 14.007973 |
# |    clip_fraction        | 0.913     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 4.82      |
# |    explained_variance   | 0.267     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.03      |
# |    n_updates            | 1370      |
# |    policy_gradient_loss | 0.0512    |
# |    std                  | 0.0589    |
# |    value_loss           | 3.57      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 986       |
# |    iterations           | 139       |
# |    time_elapsed         | 288       |
# |    total_timesteps      | 284672    |
# | train/                  |           |
# |    approx_kl            | 2.8058233 |
# |    clip_fraction        | 0.866     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 4.79      |
# |    explained_variance   | 0.443     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.43      |
# |    n_updates            | 1380      |
# |    policy_gradient_loss | 0.0806    |
# |    std                  | 0.059     |
# |    value_loss           | 4.31      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 986       |
# |    iterations           | 140       |
# |    time_elapsed         | 290       |
# |    total_timesteps      | 286720    |
# | train/                  |           |
# |    approx_kl            | 1.6937963 |
# |    clip_fraction        | 0.838     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 4.79      |
# |    explained_variance   | 0.573     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.41      |
# |    n_updates            | 1390      |
# |    policy_gradient_loss | 0.00461   |
# |    std                  | 0.0585    |
# |    value_loss           | 3.1       |
# ---------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 985      |
# |    iterations           | 141      |
# |    time_elapsed         | 292      |
# |    total_timesteps      | 288768   |
# | train/                  |          |
# |    approx_kl            | 9.752344 |
# |    clip_fraction        | 0.887    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 4.81     |
# |    explained_variance   | 0.37     |
# |    learning_rate        | 0.0003   |
# |    loss                 | 1.06     |
# |    n_updates            | 1400     |
# |    policy_gradient_loss | 0.0885   |
# |    std                  | 0.0585   |
# |    value_loss           | 2.52     |
# --------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 985       |
# |    iterations           | 142       |
# |    time_elapsed         | 295       |
# |    total_timesteps      | 290816    |
# | train/                  |           |
# |    approx_kl            | 2.2815888 |
# |    clip_fraction        | 0.793     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 4.84      |
# |    explained_variance   | 0.0489    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.23      |
# |    n_updates            | 1410      |
# |    policy_gradient_loss | -0.0113   |
# |    std                  | 0.058     |
# |    value_loss           | 3.46      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 985       |
# |    iterations           | 143       |
# |    time_elapsed         | 297       |
# |    total_timesteps      | 292864    |
# | train/                  |           |
# |    approx_kl            | 6.8106956 |
# |    clip_fraction        | 0.905     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 4.84      |
# |    explained_variance   | -0.217    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.02      |
# |    n_updates            | 1420      |
# |    policy_gradient_loss | 0.105     |
# |    std                  | 0.0589    |
# |    value_loss           | 1.85      |
# ---------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 985      |
# |    iterations           | 144      |
# |    time_elapsed         | 299      |
# |    total_timesteps      | 294912   |
# | train/                  |          |
# |    approx_kl            | 2.712628 |
# |    clip_fraction        | 0.744    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 4.85     |
# |    explained_variance   | -0.117   |
# |    learning_rate        | 0.0003   |
# |    loss                 | 1.39     |
# |    n_updates            | 1430     |
# |    policy_gradient_loss | 0.00239  |
# |    std                  | 0.0573   |
# |    value_loss           | 2.6      |
# --------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 985      |
# |    iterations           | 145      |
# |    time_elapsed         | 301      |
# |    total_timesteps      | 296960   |
# | train/                  |          |
# |    approx_kl            | 13.20537 |
# |    clip_fraction        | 0.884    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 4.9      |
# |    explained_variance   | -2.87    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.873    |
# |    n_updates            | 1440     |
# |    policy_gradient_loss | 0.04     |
# |    std                  | 0.0571   |
# |    value_loss           | 1.92     |
# --------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 985       |
# |    iterations           | 146       |
# |    time_elapsed         | 303       |
# |    total_timesteps      | 299008    |
# | train/                  |           |
# |    approx_kl            | 2.8206706 |
# |    clip_fraction        | 0.802     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 4.96      |
# |    explained_variance   | -0.0456   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1         |
# |    n_updates            | 1450      |
# |    policy_gradient_loss | 0.058     |
# |    std                  | 0.0557    |
# |    value_loss           | 2.07      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 985       |
# |    iterations           | 147       |
# |    time_elapsed         | 305       |
# |    total_timesteps      | 301056    |
# | train/                  |           |
# |    approx_kl            | 104.58722 |
# |    clip_fraction        | 0.966     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 5.02      |
# |    explained_variance   | -0.63     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.978     |
# |    n_updates            | 1460      |
# |    policy_gradient_loss | 0.282     |
# |    std                  | 0.0556    |
# |    value_loss           | 1.46      |
# ---------------------------------------

# %%
def fixed_parameters_estimate(T, u, h):
    rho_min = 100  # Minimum snow density (kg/m³)
    T_ref = 0  # Reference temperature
    alpha_T_true_fixed = 1.4
    alpha_u_true_fixed = 9.0 #4.0
    alpha_h_true_fixed = 0.2 #0.1
    true_density = rho_min + alpha_T_true_fixed * (T_ref - T) + alpha_u_true_fixed * u + alpha_h_true_fixed * h
    return np.clip(true_density, 100, 600)

def get_real_snow_density(T, u, h):
        """
        Simulate the 'true' snow density based on real-world data or a known relationship.
        You can replace this with a real-world dataset or a more sophisticated model.
        """
        rho_min = 100  # Minimum snow density (kg/m³)
        T_ref = 0  # Reference temperature
        # Example fixed parameters for the true model
        alpha_T_true = 1.5
        alpha_u_true = 10
        alpha_h_true = 0.5
        
        # True snow density based on environmental conditions
        true_density = rho_min + alpha_T_true * (T_ref - T) + alpha_u_true * u + alpha_h_true * h
        
        # Clip the density to physical limits (100 to 600 kg/m³)
        return np.clip(true_density, 100, 600)

# Load the trained model
model = PPO.load("dynamic_snow_density_model")

# Reset the environment to start the evaluation
obs = env.reset()

total_reward = 0
total_fixed_reward = 0

# Run the model for several steps to see how it adjusts the parameters in response to dynamic conditions
for i in range(50):
    # Get action (parameter adjustments) from the trained model
    action, _states = model.predict(obs)
    real_density = get_real_snow_density(obs[0],obs[1],obs[2])
    predicted_fixed_density = fixed_parameters_estimate(obs[0],obs[1],obs[2])
    # Step the environment with the chosen action
    obs, reward, done, info = env.step(action)
    fixed_reward = -abs(predicted_fixed_density - real_density)

    total_reward += reward
    total_fixed_reward += fixed_reward
    # Print out the state, action, and reward
    print(f"State: {obs}, Action (alpha_T, alpha_u, alpha_h): {action}, Reward: {reward}")
    print(f"Total reward: {total_reward}, total fixed reward: {total_fixed_reward}")
    if done:
        obs = env.reset()  # Reset environment if done (though we're not using 'done' in this case)
# Out:
# State: [-2.93363506  9.96611839  3.80367113], Action (alpha_T, alpha_u, alpha_h): [0.8437308 0.        2.275432 ], Reward: -4.317366908606601
# Total reward: -4.317366908606601, total fixed reward: -26.500789883170114
# State: [-11.47750377   7.44232678  58.50893838], Action (alpha_T, alpha_u, alpha_h): [3.1136553 9.175301  1.6221595], Reward: -0.7831495922036993
# Total reward: -5.100516500810301, total fixed reward: -37.90137311222722
# State: [-14.27440985  14.11609417  80.51903129], Action (alpha_T, alpha_u, alpha_h): [0.44853973 0.         1.8797525 ], Reward: -5.76355194979385
# Total reward: -10.864068450604151, total fixed reward: -64.04413177883359
# State: [-9.5860498   1.05716399 54.56860538], Action (alpha_T, alpha_u, alpha_h): [0.8859652 0.        2.3215256], Reward: -3.258450990551978
# Total reward: -14.122519441156129, total fixed reward: -103.74337631934262
# State: [-10.7793952   16.76313194  26.58601845], Action (alpha_T, alpha_u, alpha_h): [0.        0.        0.7882787], Reward: -9.219748012399094
# Total reward: -23.342267453555223, total fixed reward: -122.12972690132054
# State: [-17.99012822  10.30353321   5.94690752], Action (alpha_T, alpha_u, alpha_h): [2.8526447 5.7404633 2.497812 ], Reward: -3.708617288432208
# Total reward: -27.05088474198743, total fixed reward: -147.94660390118284
# State: [-4.93462101 18.71291892 25.83057664], Action (alpha_T, alpha_u, alpha_h): [4.1922317 5.238389  0.       ], Reward: -3.6012779888254443
# Total reward: -30.652162730812876, total fixed reward: -161.83322218688377
# State: [-16.62025715   0.05617183  55.92054034], Action (alpha_T, alpha_u, alpha_h): [2.2819033 6.879144  2.3787634], Reward: -6.012382445225228
# Total reward: -36.664545176038104, total fixed reward: -188.78877619756858
# State: [-9.94980294 18.63535117 17.41707042], Action (alpha_T, alpha_u, alpha_h): [0.03864788 0.         0.8303206 ], Reward: -6.378060151759826
# Total reward: -43.04260532779793, total fixed reward: -207.28313584639446
# State: [-3.77569982  9.67902856 48.16031037], Action (alpha_T, alpha_u, alpha_h): [3.3287823 7.5248475 2.099795 ], Reward: -0.06556822218379921
# Total reward: -43.10817354998173, total fixed reward: -232.13858844198958
# State: [-2.2755901   8.60423838 78.15754722], Action (alpha_T, alpha_u, alpha_h): [1.0355208 0.        2.368041 ], Reward: -8.578583433527399
# Total reward: -51.68675698350913, total fixed reward: -256.6432800900973
# State: [-9.59956949 19.4995031  79.3443183 ], Action (alpha_T, alpha_u, alpha_h): [0.        0.        1.5220038], Reward: -9.578461097552179
# Total reward: -61.265218081061306, total fixed reward: -288.92234165064036
# State: [-7.98230233  8.35536902 10.96467997], Action (alpha_T, alpha_u, alpha_h): [1.3029984 0.324484  2.7945359], Reward: -8.500499898818191
# Total reward: -69.7657179798795, total fixed reward: -333.18509718903033
# State: [-6.97166946 14.10127472 25.55083955], Action (alpha_T, alpha_u, alpha_h): [3.6051772 5.6785626 2.1776345], Reward: -0.9083181010940109
# Total reward: -70.67403608097351, total fixed reward: -345.6281004334377
# State: [-17.51507004  17.93890399  98.59282696], Action (alpha_T, alpha_u, alpha_h): [2.465896  5.3803787 2.6046314], Reward: -4.633542007863866
# Total reward: -75.30757808883737, total fixed reward: -368.09179396556135
# State: [-18.9418704   10.45918087  85.66171991], Action (alpha_T, alpha_u, alpha_h): [0.860838 0.       2.357386], Reward: -7.4590595894505896
# Total reward: -82.76663767828796, total fixed reward: -417.36005304519637
# State: [-7.68648071  7.07110009 10.96438225], Action (alpha_T, alpha_u, alpha_h): [0.4556892 0.        1.8313729], Reward: -10.325319903271236
# Total reward: -93.0919575815592, total fixed reward: -455.4119369286576
# State: [-17.28570713   6.02651192  53.66650014], Action (alpha_T, alpha_u, alpha_h): [3.448119  4.9305196 2.2948205], Reward: -1.1935263566605272
# Total reward: -94.28548393821973, total fixed reward: -466.5409997650444
# State: [-17.27101744  10.09062496  63.4937233 ], Action (alpha_T, alpha_u, alpha_h): [0.6216889 0.        1.8071561], Reward: -5.296855382743274
# Total reward: -99.582339320963, total fixed reward: -490.3960324429855
# State: [-16.71692237  17.09546743  79.18277753], Action (alpha_T, alpha_u, alpha_h): [0.71343404 0.         2.1922936 ], Reward: -7.0410196191180034
# Total reward: -106.623358940081, total fixed reward: -521.2618761348833
# State: [-17.43826936  10.79282714  97.15789529], Action (alpha_T, alpha_u, alpha_h): [1.0919174 0.        2.6378403], Reward: -8.496428955177976
# Total reward: -115.11978789525898, total fixed reward: -563.7838690631772
# State: [-18.83364273   4.585667    38.94998619], Action (alpha_T, alpha_u, alpha_h): [0.22557136 0.         1.7274307 ], Reward: -10.89751767961019
# Total reward: -126.01730557486917, total fixed reward: -605.4678917261595
# State: [-15.06462911  12.64702833  85.28017462], Action (alpha_T, alpha_u, alpha_h): [1.1356902 0.        1.695833 ], Reward: -6.14027279493618
# Total reward: -132.15757836980535, total fixed reward: -623.6219188558232
# State: [-6.93954936 16.83217949 13.77358811], Action (alpha_T, alpha_u, alpha_h): [0.5650539 0.        2.0311046], Reward: -9.982035174893497
# Total reward: -142.13961354469885, total fixed reward: -663.3594624829184
# State: [-19.31961704   2.34392799  92.45538924], Action (alpha_T, alpha_u, alpha_h): [3.1578314 7.9361    2.1485791], Reward: -0.5284823286060032
# Total reward: -142.66809587330485, total fixed reward: -685.0176733408947
# State: [-2.793618    0.68821414 65.34915115], Action (alpha_T, alpha_u, alpha_h): [0.       0.       0.910449], Reward: -14.470480789797335
# Total reward: -157.13857666310219, total fixed reward: -717.0301798044231
# State: [-17.45453412   6.16363898  92.58463594], Action (alpha_T, alpha_u, alpha_h): [0.         0.         0.58583456], Reward: -5.463352584370966
# Total reward: -162.60192924747315, total fixed reward: -737.6025010887062
# State: [-17.26668749  13.51281267  33.13393467], Action (alpha_T, alpha_u, alpha_h): [0.        0.        1.3082877], Reward: -12.983164842493352
# Total reward: -175.5850940899665, total fixed reward: -773.2869842625611
# State: [-1.92361828 11.65764838 62.61537183], Action (alpha_T, alpha_u, alpha_h): [2.4429033 2.4899538 2.9029145], Reward: -5.583018903034656
# Total reward: -181.16811299300116, total fixed reward: -798.4666460838066
# State: [-6.0907732  14.34259666 85.97300609], Action (alpha_T, alpha_u, alpha_h): [0.6599888 0.        2.241952 ], Reward: -9.11937610669247
# Total reward: -190.28748909969363, total fixed reward: -829.1012678444495
# State: [-16.38851428  18.90355092  27.67583597], Action (alpha_T, alpha_u, alpha_h): [0.6750264 0.        2.167286 ], Reward: -5.10911115105921
# Total reward: -195.39660025075284, total fixed reward: -869.8448436553432
# State: [-11.68049818   6.93456966  43.14658601], Action (alpha_T, alpha_u, alpha_h): [3.2176008 5.4665112 2.3616178], Reward: -6.028280841728815
# Total reward: -201.42488109248166, total fixed reward: -898.689996789474
# State: [-19.35264929   8.08401309  62.75435498], Action (alpha_T, alpha_u, alpha_h): [0.7510754 0.        2.2006931], Reward: -4.714406725256254
# Total reward: -206.1392878177379, total fixed reward: -919.7365920695569
# State: [-6.26371157  7.11524474 16.79532573], Action (alpha_T, alpha_u, alpha_h): [0.57351387 0.         1.9354606 ], Reward: -8.688690123430064
# Total reward: -214.82797794116797, total fixed reward: -948.5821765847238
# State: [-12.19572305   7.15665082  64.32969474], Action (alpha_T, alpha_u, alpha_h): [2.4299822 3.4096909 2.773829 ], Reward: -2.8768238717327677
# Total reward: -217.70480181290074, total fixed reward: -961.3623901985414
# State: [-17.89667572   9.15367554  68.36381084], Action (alpha_T, alpha_u, alpha_h): [0.38525158 0.         1.6980526 ], Reward: -8.09131027811324
# Total reward: -225.79611209101398, total fixed reward: -989.0375217450531
# State: [-13.34536498  13.04358623  73.8946952 ], Action (alpha_T, alpha_u, alpha_h): [0.53714365 0.         1.9936366 ], Reward: -6.6579927179487015
# Total reward: -232.45410480896268, total fixed reward: -1020.4900081060023
# State: [-7.0105485  18.20681767 87.75467094], Action (alpha_T, alpha_u, alpha_h): [0.7876067 0.        2.2969022], Reward: -7.161471821229156
# Total reward: -239.61557663019184, total fixed reward: -1057.036539396603
# State: [-14.54646039  12.05471139  87.62172651], Action (alpha_T, alpha_u, alpha_h): [1.0996078 0.        2.4864626], Reward: -10.553774257741907
# Total reward: -250.16935088793375, total fixed reward: -1102.2708131977554
# State: [-14.97275703  16.58638325  25.15251252], Action (alpha_T, alpha_u, alpha_h): [0.6174379 0.        1.960774 ], Reward: -5.3897334132868195
# Total reward: -255.55908430122057, total fixed reward: -1142.0666885767164
# State: [-14.12215124   3.59115831  12.19213655], Action (alpha_T, alpha_u, alpha_h): [3.4054925 5.1758575 2.3968399], Reward: -3.7743105048695043
# Total reward: -259.33339480609004, total fixed reward: -1167.696101289182
# State: [-0.50016387  9.11197585 36.40175612], Action (alpha_T, alpha_u, alpha_h): [2.5711985 1.6748036 1.5089827], Reward: -2.46781716049432
# Total reward: -261.80121196658433, total fixed reward: -1176.3571156920925
# State: [-16.75303966  11.33189032  37.21922847], Action (alpha_T, alpha_u, alpha_h): [1.3164996 1.4846795 2.4855814], Reward: -5.40452556544156
# Total reward: -267.20573753202586, total fixed reward: -1196.4396347640159
# State: [-3.16869869 10.94600069 50.37946294], Action (alpha_T, alpha_u, alpha_h): [1.7606544 1.3227484 2.8731105], Reward: -5.637565756555318
# Total reward: -272.8433032885812, total fixed reward: -1220.6125975947264
# State: [-10.82038637   5.68384713  71.30952352], Action (alpha_T, alpha_u, alpha_h): [1.2379065 0.233658  2.474484 ], Reward: -8.259439936352834
# Total reward: -281.102743224934, total fixed reward: -1246.9893070415342
# State: [-18.90985366  10.84915407   6.55996875], Action (alpha_T, alpha_u, alpha_h): [0.        0.        1.3406422], Reward: -13.123255191003238
# Total reward: -294.2259984159372, total fixed reward: -1275.148049868308
# State: [-8.44733842 17.14254422 87.7621632 ], Action (alpha_T, alpha_u, alpha_h): [4.266892 5.424833 0.      ], Reward: -0.5951559884713333
# Total reward: -294.82115440440856, total fixed reward: -1289.8561799247746
# State: [-2.35841669 16.02282191 45.23532534], Action (alpha_T, alpha_u, alpha_h): [0.81703156 0.         2.362609  ], Reward: -13.72812057409186
# Total reward: -308.5492749785004, total fixed reward: -1334.172106941473
# State: [-4.49591876  8.31219212 36.26119824], Action (alpha_T, alpha_u, alpha_h): [1.3884046 3.0789785 2.7874656], Reward: -7.683233363104762
# Total reward: -316.2325083416052, total fixed reward: -1364.001368118915
# State: [-18.07955969  17.19386775  60.09689924], Action (alpha_T, alpha_u, alpha_h): [1.204787   0.39177963 2.5601132 ], Reward: -6.490454355753002
# Total reward: -322.7229626973582, total fixed reward: -1383.6415115819625
